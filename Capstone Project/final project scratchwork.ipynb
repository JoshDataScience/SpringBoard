# %% [markdown]
# # Instacart Recommendation System: Feature Engineering and Modeling

# %% [markdown]
# ## Notebook by Josh Zhu

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read files

# %%
#Load all CSVs 
#creating variable names as a short way to refer to each of the cell tabs
#make sure the .csv files are in the same folder as the jupyter notebook- do not store the .csv in another folder otherwise will trigger permission error
aisles = pd.read_csv('aisles.csv')
departments = pd.read_csv('departments.csv')
order_products_prior = pd.read_csv('order_products__prior.csv')
order_products_train = pd.read_csv('order_products__train.csv')
orders = pd.read_csv('orders.csv')
products = pd.read_csv('products.csv')

# %%
#sort all user id 
#then sort all order id

orders.sort_values(by=['order_id']).head()

#remove trains

orders = orders[orders.eval_set != 'train']
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#convert order_dow into days

days = orders.order_dow.values.tolist()
def get_day():
    res = []
    for day in days:
        if day ==0:
            res.append('Sun')
        elif day ==1:
            res.append('Mon')
        elif day ==2:
            res.append('Tue')
        elif day ==3:
            res.append('Wed')
        elif day ==4:
            res.append('Thur')
        elif day ==5:
            res.append('Fri')
        elif day ==6:
            res.append('Sat')
    return res

# %%
#z = orders.copy()
#make a copy of the orders table, which we will add the day of week column to

# %%
orders['order_dow_english']=get_day()
#assigning a day of week to each number, 0= sunday,1=monday, etc
#this will add a 'order_dayofweek column to the table'

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order order_dow_english
# 0                     NaN               Tue
# 1                    15.0               Wed
# 2                    21.0               Wed
# 3                    29.0              Thur
# 4                    28.0              Thur

# %%
def weeksConverter(x):
	return x % 7

orders['days to add']=z['days_since_prior_order'].apply(weeksConverter)

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order order_dow_english  days to add
# 0                     NaN               Tue          NaN
# 1                    15.0               Wed          1.0
# 2                    21.0               Wed          0.0
# 3                    29.0              Thur          1.0
# 4                    28.0              Thur          0.0

# %%
z['days to add']=z['days_since_prior_order'].apply(weeksConverter)
orders.head(10)

#assume first is jan 1 2020
#second is jan 15
#need to make the new dates be built off the previous, not the jan 1 2020 date
#create a matrix
#all we are looking for are pairs

#only care about day of week - make sure the 2nd row is 15 days after the first, and the 3rd row is 21 day
# days after the second

#traffic on a given day
#categorize orders into different types of orders on a given day - does it have fruits, can we group them so we know what to buy/work with

#group order dow and the total # of orders
#challenge is how many

#create dates for each row, based on second row date is first row (dalorean library)
#once dates are inserted

#all the first orders are starting on the same day
#next orders will fall on similar days

#group by num of orders on any given day

#TO DO:
#ASSIGN DATES TO EVERY ORDER E.G. JAN 31 2020
#CREATE LINE CHART OR HISTOGRAM THAT SHOWS THE GROUPING OF VARIABLES - IE ON JAN 31 2020 THERE WAS 30 BOXES OF SHRIMP, 20 BOXES OF CHICKEN ORDERED
#visualizing time series on python (line chart or histogram)

#then decide how to do the forecasting

#histogram that shows - on jan 1 we have 10 orders of crab, 15 orders of shrimp
#https://pypi.org/project/Delorean/
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
# 5   3367565        1    prior             6          2                  7
# 6    550135        1    prior             7          1                  9
# 7   3108588        1    prior             8          1                 14
# 8   2295261        1    prior             9          1                 16
# 9   2550362        1    prior            10          4                  8
#
#    days_since_prior_order order_dow_english  days to add
# 0                     NaN               Tue          NaN
# ...

# %%
orders['new dow']=orders['order_dow']+orders['days to add']
orders.head()

#delete all the days below
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order order_dow_english  days to add  new day of week  \
# 0                     NaN               Tue          NaN              NaN
# 1                    15.0               Wed          1.0              4.0
# 2                    21.0               Wed          0.0              3.0
# 3                    29.0              Thur          1.0              5.0
# 4                    28.0              Thur          0.0              4.0
#
#    new dow
# 0      NaN
# 1      4.0
# 2      3.0
# 3      5.0
# 4      4.0

# %%
#if new day of week >=7, then subtract 7 to convert it to a num btwn 0-6 (can still use weeksconverter)
orders['new dow 0-6']=orders['new dow'].apply(weeksConverter)
orders.head(20)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 11   2168274        2    prior             1          2                 11
# ...

# %%
z=orders.copy()
z.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order order_dow_english  days to add  new day of week  \
# 0                     NaN               Tue          NaN              NaN
# 1                    15.0               Wed          1.0              4.0
# 2                    21.0               Wed          0.0              3.0
# 3                    29.0              Thur          1.0              5.0
# 4                    28.0              Thur          0.0              4.0
#
#    new dow  new dow 0-6
# 0      NaN          NaN
# 1      4.0          4.0
# ...

# %%
#convert order_dow into days

days = z.new dow.values.tolist()
def get_day():
    res = []
    for day in days:
        if day ==0:
            res.append('Sun')
        elif day ==1:
            res.append('Mon')
        elif day ==2:
            res.append('Tue')
        elif day ==3:
            res.append('Wed')
        elif day ==4:
            res.append('Thur')
        elif day ==5:
            res.append('Fri')
        elif day ==6:
            res.append('Sat')
    return res
# Out:
#   File "<ipython-input-109-de19bde5df76>", line 3
#     days = z.new dow.values.tolist()
#                  ^
# SyntaxError: invalid syntax
